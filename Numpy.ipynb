# %%
list = [1,2,3,4,5]

# %%
list
# Out:
# [1, 2, 3, 4, 5]

# %%
#Sebelum menggunakan numpy harus di import dulu
import numpy as np

# arr1 = np.array([1,2,3,4,5])
arr1 = np.array(list)

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr2 = np.array([2,4,6,8,10])

# %%
arr2
# Out:
# array([ 2,  4,  6,  8, 10])
