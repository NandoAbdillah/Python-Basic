# %%
A =(1,2,3,4,5,6,7,8,9,0)

# %%
len(A)
# Out:
# 10

# %%
A = (1,2,3,4,4,3,2,1,1,7,9,4)

# %%
A.count(4)
# Out:
# 3

# %%
A.count(2)
# Out:
# 2

# %%
A.index(3)
# Out:
# 2

# %%
del A #Delete the Tuple

# %%
A # Eroor karena tuple sudah di hapus
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 A # Eroor karena tuple sudah di hapus
#
# NameError: name 'A' is not defined
