# %%
print("This is my first program")
# Out:
# This is my first program

# %%
print("This is my second line..")
# Out:
# This is my second line..

# %%
#Comments are the statemens that doesn't gets executed

# %%
# Multiple lines comments
# you can make a text to comments
# in multiple lines 
# with use select all text ctrl+a
# then, click ctrl+/
