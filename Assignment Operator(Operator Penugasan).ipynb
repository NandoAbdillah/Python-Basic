# %%
x = 5

# %%
x
# Out:
# 5

# %%
x += 10

# %%
x
# Out:
# 15

# %%
x += 10

# %%
x
# Out:
# 25

# %%
x -= 10

# %%
x
# Out:
# 15

# %%
x -= 10

# %%
x
# Out:
# 5

# %%
x = x*3

# %%
x
# Out:
# 15

# %%
x *= 3

# %%
x
# Out:
# 45

# %%
x = x/5

# %%
x
# Out:
# 9.0

# %%
x /= 3

# %%
x
# Out:
# 3.0

# %%
x = x**2

# %%
x
# Out:
# 9.0

# %%
x **= 2

# %%
x
# Out:
# 81.0

# %%
x = x % 17

# %%
x
# Out:
# 13.0

# %%
x %= 10

# %%
x
# Out:
# 3.0

# %%
x %= 2

# %%
x
# Out:
# 1.0

# %%
x *= 23

# %%
x
# Out:
# 23.0

# %%
x = x//3

# %%
x
# Out:
# 7.0

# %%
x //=3

# %%
x
# Out:
# 2.0
