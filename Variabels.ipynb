# %% [markdown]
# # Variabels
# ##### Variabel di python case-sensitive jadi kamu harus memperhatikan besar kecil huruf
# ##### Beberapa peraturan variabel di python antara lain
# #####  1. Variabel tidak boleh dimulai dengan angka(1,2,3,..) dan simbol-simbol
# #####  2. Simbol yang diperbolehkan hanya (_) dan boleh terletak diawal
# #####  3. Variabel -> angka =3 dan Angka = 4 , diangggap 2 variabel yang berbeda
# #####  4. Apabila ada 2 pendevinisan variabel yang sama -> index = 3  index= 5 , maka yang diambil adalah yang terbaru (overwrite)
# #####  5. penulisan variabel dalam phyton biasanya menggunakan **snake_case cth -> umur_user**

# %%
umur = 17

# %%
umur
# Out:
# 17

# %%
umur = 18

# %%
umur
# Out:
# 18

# %%
umur_user = 22

# %%
umur_user? = 23
# Out:
#   Cell In[6], line 1
#     umur_user? = 23
#              ^
# SyntaxError: invalid syntax

# %%
umur_user
# Out:
# 22

# %%
Umur_user = 20

# %%
#Umur_user dan umur_user berbeda

Umur_user
# Out:
# 20

# %% [markdown]
# # Arithmatic Operation

# %%
#Deklarasi Variabel

x = 2
y = 3

# %%
# Addition
x+y
# Out:
# 5

# %%
# Subtraction
x-y
# Out:
# -1

# %%
# Multipication
x*y
# Out:
# 6

# %%
# Exponential
x**y
# Out:
# 8

# %%
# Exponential using pow
pow(x,y)
# Out:
# 8

# %%
# Division
x/y
# Out:
# 0.6666666666666666

# %%
# Quotient
x//y
# Out:
# 0

# %%
# Modulus
x%y
# Out:
# 2
