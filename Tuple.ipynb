# %% [markdown]
# # Tuple

# %%
A = (1,2,3,4,'Nando',False,12.56)

# %%
type(A)
# Out:
# tuple

# %%
B = [12,56,27,33,24]

# %%
type(B)
# Out:
# list

# %%
C = tuple(B)

# %%
C
# Out:
# (12, 56, 27, 33, 24)

# %%
for i in C :
    print(i)
# Out:
# 12
# 56
# 27
# 33
# 24

# %% [markdown]
# # Tuple memiliki cara Indexing dan Slicing yang sama persis dengan List !
# ##### Buka file list untuk lebih lanjut

# %%
C[-1]
# Out:
# 24

# %%
C[3:]
# Out:
# (33, 24)

# %%
C[:-3]
# Out:
# (12, 56)

# %%
C[::-1]
# Out:
# (24, 33, 27, 56, 12)

# %%
C[-1::-2]
# Out:
# (24, 27, 12)
