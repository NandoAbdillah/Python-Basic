# %%
nilai_siswa = [85, 96, 78, 96, 75, 88, 98, 97]

# %%
nilai_siswa.extend([75,85,96])

# %%
nilai_siswa.insert(1,75)

# %%
nilai_siswa
# Out:
# [85, 75, 96, 78, 96, 75, 88, 98, 97, 75, 85, 96]

# %% [markdown]
# # 1. Count
# ##### Count digunakan untuk menghitung berapa banyak anggota yang bernilai value tertentu

# %%
nilai_siswa.count(75)
# Mencari berapa banyak anggota list yang bernilai 75
# Out:
# 3

# %%
nilai_siswa.count(88)
# Out:
# 1

# %%
nilai_siswa.count(100)
# Out:
# 0

# %% [markdown]
# # 2. Index
# ##### Index digunakan untuk mengambil indeks dari anggota yang bernilai value tertentu
# ##### DAN YANG DIAMBIL ADALAH DARI ANGGOTA YANG PERTAMA SAJA

# %%
nilai_siswa.index(75)
#ada 3 75 yang di ambil adalah 75 yang paling pertama
# Out:
# 1

# %%
nilai_siswa
# Out:
# [85, 75, 96, 78, 96, 75, 88, 98, 97, 75, 85, 96]

# %%
nilai_siswa.index(88)
# Out:
# 6

# %% [markdown]
# # 3. Reverse
# ##### Reverse digunakan untuk membalik posisi awal dan akhir dari sebuah list

# %%
nilai_siswa.reverse
# Di balik

# %%
nilai_siswa
# Out:
# [96, 85, 75, 97, 98, 88, 75, 96, 78, 96, 75, 85]

# %%
# Di balik lagi
nilai_siswa.reverse()

# %%
nilai_siswa
# Out:
# [85, 75, 96, 78, 96, 75, 88, 98, 97, 75, 85, 96]

# %% [markdown]
# # 4. Sort
# ##### Sort digunakan untuk mengurutkan list dari kecil ke besar

# %%
nilai_siswa.sort()

# %%
nilai_siswa
# Out:
# [75, 75, 75, 78, 85, 85, 88, 96, 96, 96, 97, 98]

# %%
# Apabila kita ingin diurutkan dari besar ke kecil

nilai_siswa.sort(reverse = True)

# %%
nilai_siswa
# Out:
# [98, 97, 96, 96, 96, 88, 85, 85, 78, 75, 75, 75]

# %% [markdown]
# # 5. Len
# ##### Len digunakan untuk mendapatkan berapa panjang list

# %%
len(nilai_siswa)
# Out:
# 12

# %%
nilai_siswa.pop()
# Out:
# 75

# %%
nilai_siswa.remove(96)

# %%
len(nilai_siswa)
# Out:
# 10

# %%
nilai_siswa
# Out:
# [98, 97, 96, 96, 88, 85, 85, 78, 75, 75]

# %%
nilai_siswa = nilai_siswa[2:7]

# %%
nilai_siswa
# Out:
# [96, 96, 88, 85, 85]

# %%
len(nilai_siswa)
# Out:
# 5
