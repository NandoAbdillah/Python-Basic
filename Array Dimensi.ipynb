# %% [markdown]
# # Array 2 dan 3 dimensi

# %%
import numpy as np

arr = np.array([[1,2,3],[4,5,6]])

print(arr)
print(arr.ndim)
print(arr.shape)
print(arr.size)
# Out:
# [[1 2 3]
#  [4 5 6]]
# 2
# (2, 3)
# 6

# %%
arr2 = np.array([[[1,2],[1,2]], [[1,2],[1,2]], [[1,2],[1,2]]])

# %%
arr2
# Out:
# array([[[1, 2],
#         [1, 2]],
#
#        [[1, 2],
#         [1, 2]],
#
#        [[1, 2],
#         [1, 2]]])

# %%
arr2.ndim
# Out:
# 3

# %%
# Buatlah array 4-5 dimensi
