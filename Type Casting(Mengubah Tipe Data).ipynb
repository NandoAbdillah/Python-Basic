# %% [markdown]
# # Type Casting

# %%
#Integer -> Float -> String

# %%
x = '12'

# %%
y = int(x)

# %%
y
# Out:
# 12

# %%
type(y)
# Out:
# int

# %%
int('12')
# Out:
# 12

# %%
int(12.25)
# Out:
# 12

# %%
int(13.99)
# Out:
# 13

# %%
# Dalam mengcasting data float ke integer bilangan tidak akan dibulatkan melainkan hanya diambil dua bil sebelum koma saja

# %%
#Float

float('12')
# Out:
# 12.0

# %%
float(13)
# Out:
# 13.0

# %%
float(13.55)
# Out:
# 13.55

# %%
str(13.55)
# Out:
# '13.55'

# %%
str(12)
# Out:
# '12'

# %% [markdown]
# # Important Casting !

# %%
# Selain string angka '123' ia tidak dapat diubah menjadi int atau float , cth : int('Hallo123')

# %%
int('Hello123')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 int('Hello123')
#
# ValueError: invalid literal for int() with base 10: 'Hello123'

# %%
float('Hello123')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 float('Hello123')
#
# ValueError: could not convert string to float: 'Hello123'

# %%
# Mengkonfersi string berisi bilangan desimal ke integer pun akan mengakibatkan error, cth : int('17.45')

# %%
int('17.45')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 int('17.45')
#
# ValueError: invalid literal for int() with base 10: '17.45'

# %%
# harusnya langsung pakai float

# %%
float('17.45')
# Out:
# 17.45

# %%
#atau

# %%
int(float('17.45'))
# Out:
# 17

# %%
type(int(float('17.45')))
# Out:
# int
