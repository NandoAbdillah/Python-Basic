# %%
import numpy as np

arr1 = np.array([1])
arr1
# Out:
# array([1])

# %%
# Memeriksa dimensi array

arr1.ndim
# Out:
# 1

# %%
arr2 = np.array([1,2,3])
arr2
# Out:
# array([1, 2, 3])

# %%
arr2.ndim
# Out:
# 1

# %%
arr2.shape
# Out:
# (3,)

# %%
arr2.size
# Out:
# 3

# %%
arr3 = np.array([1,2,3,4])
print(arr3.ndim)
print(arr3.shape)
print(arr3.size)
# Out:
# 1
# (4,)
# 4
