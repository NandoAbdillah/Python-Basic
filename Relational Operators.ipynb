# %%
5 < 10
# Out:
# True

# %%
5 > 10
# Out:
# False

# %%
x = 15
y = 20

# %%
x > y
# Out:
# False

# %%
x < y
# Out:
# True

# %%
# Less then equal to

# %%
11 <= 12
# Out:
# True

# %%
13 <= 12
# Out:
# False

# %%
12 <= 12
# Out:
# True

# %%
12 < 12
# Out:
# False

# %%
x != y
# Out:
# True

# %%
x != 15
# Out:
# False

# %%
x == y
# Out:
# False
