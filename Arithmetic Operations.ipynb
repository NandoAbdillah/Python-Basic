# %% [markdown]
# # Addition

# %%
10+4
# Out:
# 14

# %%
1234+1234+4321+4321
# Out:
# 11110

# %%
78.5+23.5
# Out:
# 102.0

# %%
-765.125+765.0756
# Out:
# -0.04939999999999145

# %%
-125+555
# Out:
# 430

# %% [markdown]
# # Substraction

# %%
10-4
# Out:
# 6

# %%
-22-22-22
# Out:
# -66

# %%
23-56
# Out:
# -33

# %%
1-2-3-4-5-6-7-8-9
# Out:
# -43

# %%
9-8-7-6-5-4-3-2-1
# Out:
# -27

# %% [markdown]
# # Multiplication

# %%
7*2*4
# Out:
# 56

# %%
-2*4*-72
# Out:
# 576

# %%
2*9-8-3*-125*20
# Out:
# 7510

# %% [markdown]
# # Exponential

# %%
2*2*2
# Out:
# 8

# %%
#it's not efective,so instead use 2*2*2 we use :

# %%
2**3
# Out:
# 8

# %%
#or

# %%
pow(2,3)
# Out:
# 8

# %% [markdown]
# # Division

# %%
10/3
# Out:
# 3.3333333333333335

# %%
4/2/4
# Out:
# 0.5

# %%
12/3/0.5
# Out:
# 8.0

# %%
0.2/0.5/2
# Out:
# 0.2

# %% [markdown]
# # Quation

# %%
10/3
# Out:
# 3.3333333333333335

# %%
#10/3 hasilnya dalam pembagian biasa adalah seperti yang diatas
#Namun Quation berfungsi untuk mengambil angka yang pembagian terdekat 
#Contoh disini 10/3 adalah 3+3+3 +1
#3+3+3 (3 diulang 3 kali ) ini disebut Quation
#sedangkan angka sisanya disebut Modulus

# %%
10//3
# Out:
# 3

# %%
12/10
# Out:
# 1.2

# %%
12//10
# Out:
# 1

# %% [markdown]
# # Modulus

# %%
#Seperti yang dijelaskan di atas modulus adalah sisa bagi, contoh

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
10%3
# Out:
# 1

# %%
#Sisanya 1

# %%
27/20
# Out:
# 1.35

# %%
27//20
# Out:
# 1

# %%
27%20
# Out:
# 7

# %%
#Maka bisa ditarik kesimpulan untuk mencari angka yang dubagi jika hanya diketahui modulus,quation,dan angka pembagi adalah
# Angka yang dibagi = Angka Pembagi * hasil quation + hasil modulus
# Angka = 20*1+7

# %%
20*1+7
# Out:
# 27
