# %% [markdown]
# # Data Type

# %%
x=25

# %%
type(x)
# Out:
# int

# %%
x='25'

# %%
type(x)
# Out:
# str

# %%
x=25.20

# %%
type(x)
# Out:
# float

# %%
x=True

# %%
type(x)
# Out:
# bool

# %%
x=False

# %%
type(x)
# Out:
# bool

# %%
x= 3 + 2i
# Out:
#   Cell In[11], line 1
#     x= 3 + 2i
#            ^
# SyntaxError: invalid decimal literal

# %%
#Error karena variabel khusus yang diizinkan untuk tipe data complex adalah j

# %%
x= 3 + 2j

# %%
type(x)
# Out:
# complex

# %%
x= [1,2,3,'Hallo']

# %%
x
# Out:
# [1, 2, 3, 'Hallo']

# %%
type(x)
# Out:
# list

# %%
x= (1,2,3,'Hello')

# %%
x
# Out:
# (1, 2, 3, 'Hello')

# %%
type(x)
# Out:
# tuple

# %%
x= {1,2,3,'Hello'}

# %%
x
# Out:
# {1, 2, 3, 'Hello'}

# %%
type(x)
# Out:
# set

# %%
x = {'Minggu':1, 'Senin':2}

# %%
x
# Out:
# {'Minggu': 1, 'Senin': 2}

# %%
#'Minggu' => Key , 1 => value

# %%
type(x)
# Out:
# dict
