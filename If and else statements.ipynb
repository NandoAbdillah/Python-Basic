# %% [markdown]
# # Pengujian

# %%
#Contoh pengujian

x= 15
if (x>5):
    print("x is greater than 5")
# Out:
# x is greater than 5

# %%
x= 7
if (x<=5):
    print("x is lesser than or equal 5")
elif ((x>5) and (x<10)):
    print("x is beetween 5 and 10")
else :
    print("x is greater than or equal 10")
# Out:
# x is beetween 5 and 10

# %%
# Anda dapat menggunakan and atau & dan or atau | , berikut ini penerapannya
x = 27

if (x%2==0) : 
    print("x adalah bilangan Genap")
elif ((x%3==0) | (x%5==0) | (x%7==0)) :
    print("x adalah bilangan yang dapat dibagi dengan 3 atau 5 atau 7")
else :
    print(f"x hanya bisa dibagi dengan {x} dan 1 (Bilangan Prima)")
# Out:
# x adalah bilangan yang dapat dibagi dengan 3 atau 5 atau 7
