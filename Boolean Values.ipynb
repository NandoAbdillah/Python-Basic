# %%
10
# Out:
# 10

# %%
bool(10)
# Out:
# True

# %%
bool(5)
# Out:
# True

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
#Hanya bilangan 0 yang bernilai FALSE

# %%
bool(0.001)
# Out:
# True

# %%
bool(-123456789)
# Out:
# True

# %%
True * True
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
False * True
# Out:
# 0

# %%
False * True
# Out:
# 0

# %%
False * False
# Out:
# 0

# %%
True + True
# Out:
# 2

# %%
True + False
# Out:
# 1

# %%
False + True
# Out:
# 1

# %%
False + False
# Out:
# 0

# %%
# Di dalam python operator and dan or dilambangkan & , | ditulis 1 kali tidak seperti javascript ataupun php

# %% [markdown]
# # AND &

# %%
True & True
# Out:
# True

# %%
True & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %% [markdown]
# # OR |

# %%
True | True
# Out:
# True

# %%
True | False
# Out:
# True

# %%
False | True
# Out:
# True

# %%
False | False
# Out:
# False

# %% [markdown]
# # Penerapan dalam Bilangan

# %%
x = 10

# %%
(x > 12) & (x <10)
# Out:
# False

# %%
(x >5) & ( x !=5)
# Out:
# True

# %%
(x < 15) | (x==5)
# Out:
# True

# %%
(x > 10) | (x == 15)
# Out:
# False

# %%
(x > 5) & (x < 10) | (x == 3) | (x >= 15) & (x!=12)
# Out:
# False
