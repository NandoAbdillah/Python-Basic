# %% [markdown]
# # First Program

# %% [markdown]
# ##### this is my **first jupyter notebook**
# ##### you will se a change in [] when you execute cell (the number in [] will increase every u *execute the cells* -> it will increase even u *add another cell*)

# %%
#for insert cell above , click esc then click a

# %%
print("Hey there!")
# Out:
# Hey there!

# %%
#for insert cell bellow , click esc then click b

# %%
#for delete cell click esc then click dd
